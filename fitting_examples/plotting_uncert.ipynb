# %%
import fitting_tools as ft
import time
import numpy as np
import matplotlib.pylab as plt
import random
# %matplotlib notebook
import fitting_tools_main as ftm
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 15 days

# %%
#Calculate the mean and std of frac pulls
def calc_mean_std_of_pulls(values):
    pulls=(values[0]-values[1])/values[2]
    return (np.mean(pulls),np.std(pulls))

def calc_avg_uncert(values):
    return np.mean(values[2]),np.std(values[2])

# %%
print "no bootstrapping samples"
infile_name='frac_values_trial2_sig200_bkg1000_MCsig1000_MCbkg1000_bs0_nn3_1dimension.dat'
values=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
print calc_mean_std_of_pulls(values)

infile_name='frac_values_trial2_sig200_bkg1000_MCsig1000_MCbkg1000_bs0_nn5_1dimension.dat'
values1=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
print calc_mean_std_of_pulls(values1)

infile_name='frac_values_trial2_sig200_bkg1000_MCsig1000_MCbkg1000_bs0_nn10_1dimension.dat'
values2=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
print calc_mean_std_of_pulls(values2)

infile_name='frac_values_trial2_sig20_bkg100_MCsig1000_MCbkg1000_bs0_nn3_1dimension.dat'
values3=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
print calc_mean_std_of_pulls(values3)

infile_name='frac_values_trial2_sig20_bkg100_MCsig1000_MCbkg1000_bs0_nn5_1dimension.dat'
values4=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
print calc_mean_std_of_pulls(values4)

infile_name='frac_values_trial2_sig20_bkg100_MCsig1000_MCbkg1000_bs0_nn10_1dimension.dat'
values5=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
print calc_mean_std_of_pulls(values5)
# Out:
# no bootstrapping samples
# (0.1106350631176435, 1.151868347032331)
# (-0.096315716887037661, 1.1950526979334333)
# (-0.50863779757196781, 1.1620909185686583)
# (0.12331553022680047, 1.0539162564035884)
# (-0.050257006904853525, 1.0804458896490021)
# (-0.080175859488953269, 1.0527057622258378)

# %%
#infile_name='frac_values_trial1_sig200_bkg1000_MCsig1000_MCbkg1000_bs1000_nn3_1dimension.dat'
#values1=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
#print calc_mean_std_of_pulls(values1)

#infile_name='frac_values_trial1_sig200_bkg1000_MCsig1000_MCbkg1000_bs1000_nn5_1dimension.dat'
#values2=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
#print calc_mean_std_of_pulls(values2)

infile_name='frac_values_trial1_sig200_bkg1000_MCsig1000_MCbkg1000_bs1000_nn10_1dimension.dat'
values8=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
print calc_mean_std_of_pulls(values8)


#infile_name='frac_values_trial1_sig20_bkg100_MCsig1000_MCbkg1000_bs1000_nn3_1dimension.dat'
#values4=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
#print calc_mean_std_of_pulls(values4)

#infile_name='frac_values_trial2_sig20_bkg100_MCsig1000_MCbkg1000_bs0_nn5_1dimension.dat'
#values5=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
#print calc_mean_std_of_pulls(values5)

infile_name='frac_values_trial2_sig20_bkg100_MCsig1000_MCbkg1000_bs0_nn10_1dimension.dat'
values11=np.loadtxt(infile_name, delimiter=' ', unpack=True,dtype=float)
print calc_mean_std_of_pulls(values11)
# Out:
# (-0.43108085215820452, 1.1414246045834591)
# (-0.080175859488953269, 1.0527057622258378)

# %%
plt.figure(figsize=(12,15))

labels = ['nn=3',
          'nn=5',
          'nn=10',
          'nn=3, smaller dataset',
          'nn=5, smaller dataset',
          'nn=10, smaller dataset',
          'nn=10',
          'nn=10 smaller dataset'
         ]

fmt = ['ro','bo','go','rs','bs','gs','r*','b*']
color=['red','blue','green','red','blue','green','red','blue']

for v,l,f,x,c in zip([values,values1,values2,values3,values4,values5,values8,values11],labels,fmt,range(9),color):
    y,std = calc_avg_uncert(v)
    #print 'min of uncert %f' % min(v[2])
    #print 'max of uncert %f' % max(v[2])
    #print np.std(v[2])
    yerr=std
    print yerr
    ecolor=fmt[0]
    plt.plot(x,y,f,label=l,markersize=10)
    plt.errorbar(x,y,yerr=yerr,color=c)
    

#plt.ylim(0.01,0.044)
#plt.xlim(-.5,9)
plt.legend(loc='upper left',fontsize=10)
plt.xlabel('Type of test')
plt.ylabel('Average Uncertainty')
plt.savefig('Average Uncertainty')
# Out:
# <img src="data:image/png;base64,...">
# 0.000393691729738
# 0.000428409860268
# 0.000410234346563
# 0.00396058024244
# 0.00395412212094
# 0.00384797990003
# 0.000405996984107
# 0.00384797990003

# %%
plt.figure(figsize=(10,6))

labels = ['nn=3',
          'nn=5',
          'nn=10',
          'nn=3, smaller dataset',
          'nn=5, smaller dataset',
          'nn=10, smaller dataset',
          'nn=10',
          'nn=10 smaller dataset'
         ]

fmt = ['ro','bo','go','rs','bs','gs','r*','b*']

for v,l,f in zip([values,values1,values2,values3,values4,values5,values8,values11],labels,fmt):
    x,y = calc_mean_std_of_pulls(v) 
    print x
    plt.plot(y,x,f,label=l,markersize=20)
    
#for v,f in zip([values,values2,values3,values4,values5,values6,values7,values8,values9],fmt):
#    x,y = calc_mean_std_of_pulls(v) 
#    plt.plot(y,x,f,markersize=20)

#plt.ylim(-2.0,1.0)
plt.xlim(1.04,1.25)
plt.legend(loc='lower right',fontsize=10)
# Out:
# <img src="data:image/png;base64,...">
# 0.110635063118
# -0.096315716887
# -0.508637797572
# 0.123315530227
# -0.0502570069049
# -0.080175859489
# -0.431080852158
# -0.080175859489
