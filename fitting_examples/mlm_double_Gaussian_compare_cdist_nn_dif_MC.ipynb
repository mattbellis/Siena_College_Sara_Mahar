# %%
import numpy as np
import matplotlib.pylab as plt
import math as math
from scipy.optimize import fmin
from iminuit import Minuit, describe, Struct
from scipy.spatial import distance
from scipy.sparse import vstack
import time
import seaborn as sns
# %matplotlib  notebook

# %%
def nn(data0,data1,r=None,nneighbors=None):
    ret = -1
    ret_list=[]
    if r is not None and nneighbors is not None:
        exit(-1)
        return ret
    elif r is not None and nneighbors is None:
        rsq = r*r
        for d in data0.transpose():
            count=0
            diffx=d[0]-data1[0]
            diffy=d[1]-data1[1]
            diff= diffx*diffx + diffy*diffy
            count = len(diff[diff<rsq])
            ret_list.append(float(count)/(float(len(data1[0]))*r))
        ret_list = np.array(ret_list)
        return ret_list
    elif r is None and nneighbors is not None:
        for d in data0.transpose():
            diffx=d[0]-data1[0]
            diffy=d[1]-data1[1]
            diff= diffx*diffx + diffy*diffy
            diff.sort()
            radius2 = diff[nneighbors-1]
            ret_list.append(1./(radius2))
#            ret_list.append(1./np.sqrt(radius2))
            #ret_list.append(float(nneighbors)/(np.pi*radius2)) # Let's do the inverse of the radius squared, since this is a 2D problem.
            #ret_list.append(float(nneighbors)/np.sqrt(radius2)) # 

        ret_list = np.array(ret_list)
        return ret_list
    return ret

# %%
# Add code to the following function so that it takes in two datasets, loops over one of them, and finds
# information about the nearest neighbors in the other dataset, based on a flag. 

def nncdist(data0,data1,r=None,nneighbors=None):   
    ret = -1
    ret_list=[]
    if r is not None and nneighbors is not None:
        exit(-1)
        return ret
    elif r is not None and nneighbors is None:
        combined = data0.transpose()
        combined1 = data1.transpose()
        dist=distance.cdist(combined,combined1,'euclidean')
        for num in dist:
            count=len(num[num<r])
            ret_list.append(float(count)/(float(len(data1[0]))*r))
        ret_list = np.array(ret_list)
        return ret_list
    elif r is None and nneighbors is not None:
        for num0 in data0:
            diff = np.abs(num0 - data1)
            diff.sort()
            radius2 = diff[nneighbors-1]
            ret_list.append(1./np.sqrt(radius2)) # radius 
        ret_list = np.array(ret_list)
        return ret_list
    return ret

# %%
def normal(x,mean,width):
    return (1.0/(width*np.sqrt(2*np.pi)))*(np.exp(-(x-mean)**2/(2*(width**2))))

# A product of two Gaussians
def signal_2D(npts,means,sigmas):
    pts = []
    for m,s in zip(means,sigmas):
        pts.append(np.random.normal(m,s,npts))
    pts = np.array(pts)
    
    return pts
    

# Flat in 2D
def background_2D(npts,lovals,hivals):
    pts = []
    for lo,hi in zip(lovals,hivals):
        width = hi-lo
        pts.append(lo + width*np.random.random(npts))
    pts = np.array(pts)
    return pts

# Helper function to generate signal and background at the same time
def gen_sig_and_bkg(npts,means,sigmas,lovals,hivals):
    sigpts = signal_2D(npts[0],means,sigmas)
    bkgpts = background_2D(npts[1],lovals,hivals)
    data = [sigpts[0].copy(),sigpts[1].copy()]
    data[0] = np.append(data[0],bkgpts[0])
    data[1] = np.append(data[1],bkgpts[1])
    data = np.array(data)
    return data

# %%
# Test the tools to generate the datasets.
sigpts = signal_2D(2000,[5.0,7.0],[0.1,0.1])
sns.jointplot(sigpts[0],sigpts[1],kind='hex')
bkgpts = background_2D(10000,[3.5,5],[6,9])
sns.jointplot(bkgpts[0],bkgpts[1],kind='hex')
data1 = [sigpts[0].copy(),sigpts[1].copy()]
data1[0] = np.append(data1[0],bkgpts[0])
data1[1] = np.append(data1[1],bkgpts[1])
data1 = np.array(data1)
sns.jointplot(data1[0],data1[1],kind='hex')
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
nbkg = 1000
sigmeans = [5.0,7.0]
bkglos = [3.5,5]
bkghis = [6,9]

def calc_pull(iterations, nsig, nMC_sig, nMC_bkg, nneigh,cdist_bool,sigwidths):
    
    pull_frac_list=[]
    average_best_frac = 0
    frac = []
    fit_frac = []
    fit_frac_uncert = []
    frac_org = nsig/float(nsig+nbkg)

    for num in range(iterations):
        
        nsig_iteration = np.random.poisson(nsig)
        nbkg_iteration = np.random.poisson(nbkg)
        data = gen_sig_and_bkg([nsig_iteration,nbkg_iteration],sigmeans,sigwidths,bkglos,bkghis)
        
        signal_points= signal_2D(nMC_sig,sigmeans,sigwidths)
        background_points = background_2D(nMC_bkg,bkglos,bkghis)
        frac_iteration = float(nsig_iteration)/(float(nbkg_iteration+nsig_iteration))
        frac.append(frac_iteration)
        

        signal_prob=nn(data,signal_points, nneighbors=nneigh)
        background_prob = nn(data,background_points, nneighbors=nneigh)

        def tot_prob(frac):
            tot_prob=[]
            #tot_prob.append(frac*signal_prob*(nMC_sig/(nMC_sig+nMC_bkg)) + ((1-frac)*background_prob)*(nMC_bkg)/(nMC_sig+nMC_bkg))
            tot_prob.append(frac*signal_prob/(nMC_sig) + ((1-frac)*background_prob)/(nMC_bkg))
            return np.array(tot_prob)
        
        def probability(frac):
            prob=tot_prob(frac)
            return -np.log(prob[prob>0]).sum()
        
        m1=Minuit(probability,frac= 0.2,limit_frac=(0.001,1),error_frac=0.001,errordef = 0.5,print_level=0)
        m1.migrad()

        if (m1.get_fmin().is_valid):
            param=m1.values
            err=m1.errors
            fit_frac.append(param["frac"])
            fit_frac_uncert.append(err["frac"])
            pull_frac=(frac_org-param["frac"])/err["frac"]
            pull_frac_list.append(pull_frac)
            
    return pull_frac_list, frac, fit_frac, fit_frac_uncert,iterations

# %%
means1=[]
stds1=[]

sig_list=[200]
MC_sig_list=[1000]
MC_bkg=5000
#rad_list=[0.1]
#width_list=[0.06,.15]
width_list=[0.1]
n=[5]

niterations = 100


pulls_list ={}
for sig in sig_list:
    for MC_sig in MC_sig_list: #,100000]:
        start = time.time()
        for nneighbors in n:#,0.05,0.1,0.15,0.20]: #, 0.10,0.20,0.50]:
            for w in width_list:
                sig_widths=[w,w]
                start = time.time()
                print 'number of signal points: %s \t number of MC point: %s \tradius: %s \t width: %s' % (sig,MC_sig,nneighbors,w)
                pulls,org_vals1,fit_vals1,fit_uncerts1,iteration= calc_pull(niterations, sig, MC_sig, MC_bkg, nneighbors,False,sig_widths)
                name='MC' +str(MC) + 'rad'+str(nneighbors)
                pulls_list[name]=pulls

                parameters_mean = {'signal': sig, 'MC_points': MC, 'nearest neighbors': nneighbors, 'mean pulls': np.mean(pulls), 'width':w}
                means1.append(parameters_mean)
                parameters_std = {'signal': sig, 'MC_points': MC, 'nearest neighbors': nneighbors, 'mean stds': np.std(pulls),'width':w}
marker_sizes=[5,10,60]
labels=[]


for item in means1:
    if item['width']==width_list[0]:
        label='MC=' + str(item['MC_points']) + ' signal=' + str(item['signal'])
        
    
        if item['MC_points']== MC_list[0]:
            color=colors[0]
        #if item['MC_points']==MC_list[1]:
        #    color=colors[1]

        if item['signal']==sig_list[0]:
            marker=markers[0]
        #if item['signal']==sig_list[1]:
        #    marker=markers[1]
        for x in labels:
            if label==x:
                label=""       
        plt.plot(item['nearest neighbors'],item['mean pulls'], color=color, marker=marker,label=label)
        labels.append(label)

plt.legend(loc='lower right')
plt.title("Means with widths of "+str(width_list[0]))
           
plt.figure()
labels=[]
           
for item in means1:
    if item['width']==width_list[1]:
        label='MC=' + str(item['MC_points']) +  ' signal=' + str(item['signal'])
    
        if item['MC_points']== MC_list[0]:
            color=colors[0]
        #if item['MC_points']==MC_list[1]:
        #    color=colors[1]

        if item['signal']==sig_list[0]:
            marker=markers[0]
        #if item['signal']==sig_list[1]:
        #    marker=markers[1]

        for x in labels:
            if label==x:
                label=""
            
        plt.plot(item['nearest neighbors'],item['mean pulls'], color=color, marker=marker,label=label)
        labels.append(label)

plt.legend(loc='lower right')    

plt.title("Means with widths of "+str(width_list[1]))


plt.figure()
labels=[]
           
for item in stds1:
    if item['width']==width_list[0]:
        label='MC=' + str(item['MC_points']) +  ' signal=' + str(item['signal'])
    
        if item['MC_points']== MC_list[0]:
            color=colors[0]
        #if item['MC_points']==MC_list[1]:
        #    color=colors[1]

        if item['signal']==sig_list[0]:
            marker=markers[0]
        #if item['signal']==sig_list[1]:
        #    marker=markers[1]

        for x in labels:
            if label==x:
                label=""
            
        plt.plot(item['nearest neighbors'],item['mean stds'], color=color, marker=marker,label=label)
        labels.append(label)

plt.legend(loc='lower right')   

plt.title("Standard Deviations with widths of "+str(width_list[0]))




plt.figure()
labels=[]
           
for item in stds1:
    if item['width']==width_list[1]:
        label='MC=' + str(item['MC_points']) +  ' signal=' + str(item['signal'])
    
        if item['MC_points']== MC_list[0]:
            color=colors[0]
        #if item['MC_points']==MC_list[1]:
        #    color=colors[1]

        if item['signal']==sig_list[0]:
            marker=markers[0]
        #if item['signal']==sig_list[1]:
        #    marker=markers[1]

        for x in labels:
            if label==x:
                label=""
            
        plt.plot(item['nearest neighbors'],item['mean stds'], color=color, marker=marker,label=label)
        labels.append(label)

plt.legend(loc='lower right')

plt.title("Standard Deviations with widths of "+str(width_list[1]))
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
#800 signal points
#pythagorean method
means800=[]
stds800=[]

#sig_widths = [0.6,0.6]
sig_list=[200,400]
MC_list=[10000,100000]
rad_list=[0.01,0.05,0.1,0.15,0.20]
width_list=[0.06,.15]

pulls_list ={}
for sig in sig_list:
    for MC in MC_list: #,100000]:
        start = time.time()
        for rad in rad_list:#,0.05,0.1,0.15,0.20]: #, 0.10,0.20,0.50]:
            for w in width_list:
                sign_widths=[w,w]
                start = time.time()
                print 'number of signal points: %s \t number of MC point: %s \tradius: %s \t width: %s' % (sig,MC,rad,w)
                pulls,org_vals1,fit_vals1,fit_uncerts1,iteration= calc_pull(10, sig, MC, rad,False,sig_widths)
                name='MC' +str(MC) + 'rad'+str(rad)
                pulls_list[name]=pulls

                parameters_mean = {'signal': sig, 'MC_points': MC, 'radius': rad, 'mean pulls': np.mean(pulls), 'width':w}
                means800.append(parameters_mean)
                parameters_std = {'signal': sig, 'MC_points': MC, 'radius': rad, 'mean stds': np.std(pulls),'width':w}
                stds800.append(parameters_std)
                print "time to calc 10 iterations: %f s" % (time.time() - start)        

print means800
print stds800
print '--------------------'
# Out:
# number of signal points: 200 	 number of MC point: 10000 	radius: 0.01 	 width: 0.06
# time to calc 10 iterations: 0.938094 s
# number of signal points: 200 	 number of MC point: 10000 	radius: 0.01 	 width: 0.15
# time to calc 10 iterations: 0.917374 s
# number of signal points: 200 	 number of MC point: 10000 	radius: 0.05 	 width: 0.06
# time to calc 10 iterations: 0.937858 s
# number of signal points: 200 	 number of MC point: 10000 	radius: 0.05 	 width: 0.15
# time to calc 10 iterations: 0.956699 s
# number of signal points: 200 	 number of MC point: 10000 	radius: 0.1 	 width: 0.06
# time to calc 10 iterations: 0.972548 s
# number of signal points: 200 	 number of MC point: 10000 	radius: 0.1 	 width: 0.15
# time to calc 10 iterations: 0.939491 s
# number of signal points: 200 	 number of MC point: 10000 	radius: 0.15 	 width: 0.06
# time to calc 10 iterations: 0.977794 s
# number of signal points: 200 	 number of MC point: 10000 	radius: 0.15 	 width: 0.15
# time to calc 10 iterations: 0.993756 s
# number of signal points: 200 	 number of MC point: 10000 	radius: 0.2 	 width: 0.06
# time to calc 10 iterations: 1.008023 s
# number of signal points: 200 	 number of MC point: 10000 	radius: 0.2 	 width: 0.15
# time to calc 10 iterations: 1.072400 s
# number of signal points: 200 	 number of MC point: 100000 	radius: 0.01 	 width: 0.06
# time to calc 10 iterations: 11.354566 s
# number of signal points: 200 	 number of MC point: 100000 	radius: 0.01 	 width: 0.15
# time to calc 10 iterations: 11.349339 s
# number of signal points: 200 	 number of MC point: 100000 	radius: 0.05 	 width: 0.06
# time to calc 10 iterations: 11.570447 s
# number of signal points: 200 	 number of MC point: 100000 	radius: 0.05 	 width: 0.15
# time to calc 10 iterations: 11.355541 s
# number of signal points: 200 	 number of MC point: 100000 	radius: 0.1 	 width: 0.06
# time to calc 10 iterations: 11.447588 s
# number of signal points: 200 	 number of MC point: 100000 	radius: 0.1 	 width: 0.15
# time to calc 10 iterations: 11.457692 s
# number of signal points: 200 	 number of MC point: 100000 	radius: 0.15 	 width: 0.06
# time to calc 10 iterations: 11.940998 s
# number of signal points: 200 	 number of MC point: 100000 	radius: 0.15 	 width: 0.15
# time to calc 10 iterations: 11.930034 s
# number of signal points: 200 	 number of MC point: 100000 	radius: 0.2 	 width: 0.06
# time to calc 10 iterations: 11.959680 s
# number of signal points: 200 	 number of MC point: 100000 	radius: 0.2 	 width: 0.15
# time to calc 10 iterations: 12.299148 s
# number of signal points: 400 	 number of MC point: 10000 	radius: 0.01 	 width: 0.06
# time to calc 10 iterations: 1.078666 s
# number of signal points: 400 	 number of MC point: 10000 	radius: 0.01 	 width: 0.15
# time to calc 10 iterations: 1.056221 s
# number of signal points: 400 	 number of MC point: 10000 	radius: 0.05 	 width: 0.06
# time to calc 10 iterations: 1.104350 s
# number of signal points: 400 	 number of MC point: 10000 	radius: 0.05 	 width: 0.15
# time to calc 10 iterations: 1.089459 s
# number of signal points: 400 	 number of MC point: 10000 	radius: 0.1 	 width: 0.06
# time to calc 10 iterations: 1.110142 s
# number of signal points: 400 	 number of MC point: 10000 	radius: 0.1 	 width: 0.15
# time to calc 10 iterations: 1.103838 s
# number of signal points: 400 	 number of MC point: 10000 	radius: 0.15 	 width: 0.06
# time to calc 10 iterations: 1.120097 s
# number of signal points: 400 	 number of MC point: 10000 	radius: 0.15 	 width: 0.15
# time to calc 10 iterations: 1.139029 s
# number of signal points: 400 	 number of MC point: 10000 	radius: 0.2 	 width: 0.06
# time to calc 10 iterations: 1.186909 s
# number of signal points: 400 	 number of MC point: 10000 	radius: 0.2 	 width: 0.15
# time to calc 10 iterations: 1.183908 s
# number of signal points: 400 	 number of MC point: 100000 	radius: 0.01 	 width: 0.06
# time to calc 10 iterations: 13.176403 s
# number of signal points: 400 	 number of MC point: 100000 	radius: 0.01 	 width: 0.15
# time to calc 10 iterations: 13.376202 s
# number of signal points: 400 	 number of MC point: 100000 	radius: 0.05 	 width: 0.06
# time to calc 10 iterations: 13.221200 s
# number of signal points: 400 	 number of MC point: 100000 	radius: 0.05 	 width: 0.15
# time to calc 10 iterations: 13.323829 s
# number of signal points: 400 	 number of MC point: 100000 	radius: 0.1 	 width: 0.06
# time to calc 10 iterations: 13.574570 s
# number of signal points: 400 	 number of MC point: 100000 	radius: 0.1 	 width: 0.15
# time to calc 10 iterations: 13.526164 s
# number of signal points: 400 	 number of MC point: 100000 	radius: 0.15 	 width: 0.06
# time to calc 10 iterations: 13.937717 s
# number of signal points: 400 	 number of MC point: 100000 	radius: 0.15 	 width: 0.15
# time to calc 10 iterations: 13.788904 s
# number of signal points: 400 	 number of MC point: 100000 	radius: 0.2 	 width: 0.06
# time to calc 10 iterations: 14.370713 s
# number of signal points: 400 	 number of MC point: 100000 	radius: 0.2 	 width: 0.15
# time to calc 10 iterations: 14.319210 s
# [{'width': 0.06, 'signal': 200, 'radius': 0.01, 'mean pulls': -14.623735349645278, 'MC_points': 10000}, {'width': 0.15, 'signal': 200, 'radius': 0.01, 'mean pulls': -13.818155506024249, 'MC_points': 10000}, {'width': 0.06, 'signal': 200, 'radius': 0.05, 'mean pulls': -1.8075344051048923, 'MC_points': 10000}, {'width': 0.15, 'signal': 200, 'radius': 0.05, 'mean pulls': -1.1789997135745265, 'MC_points': 10000}, {'width': 0.06, 'signal': 200, 'radius': 0.1, 'mean pulls': -0.065541408744767132, 'MC_points': 10000}, {'width': 0.15, 'signal': 200, 'radius': 0.1, 'mean pulls': -0.23433298092783711, 'MC_points': 10000}, {'width': 0.06, 'signal': 200, 'radius': 0.15, 'mean pulls': 0.93505118677786814, 'MC_points': 10000}, {'width': 0.15, 'signal': 200, 'radius': 0.15, 'mean pulls': -0.018705243487416846, 'MC_points': 10000}, {'width': 0.06, 'signal': 200, 'radius': 0.2, 'mean pulls': 0.41289032480071686, 'MC_points': 10000}, {'width': 0.15, 'signal': 200, 'radius': 0.2, 'mean pulls': -0.020597547183282945, 'MC_points': 10000}, {'width': 0.06, 'signal': 200, 'radius': 0.01, 'mean pulls': -4.8791878686310231, 'MC_points': 100000}, {'width': 0.15, 'signal': 200, 'radius': 0.01, 'mean pulls': -4.3691792210936367, 'MC_points': 100000}, {'width': 0.06, 'signal': 200, 'radius': 0.05, 'mean pulls': 0.081157132012882396, 'MC_points': 100000}, {'width': 0.15, 'signal': 200, 'radius': 0.05, 'mean pulls': -0.088591781276186415, 'MC_points': 100000}, {'width': 0.06, 'signal': 200, 'radius': 0.1, 'mean pulls': -0.045234730735094861, 'MC_points': 100000}, {'width': 0.15, 'signal': 200, 'radius': 0.1, 'mean pulls': -0.30318614737010097, 'MC_points': 100000}, {'width': 0.06, 'signal': 200, 'radius': 0.15, 'mean pulls': -0.63435782863686296, 'MC_points': 100000}, {'width': 0.15, 'signal': 200, 'radius': 0.15, 'mean pulls': 0.48770381413577801, 'MC_points': 100000}, {'width': 0.06, 'signal': 200, 'radius': 0.2, 'mean pulls': 0.88530103412315131, 'MC_points': 100000}, {'width': 0.15, 'signal': 200, 'radius': 0.2, 'mean pulls': 0.081242150885329018, 'MC_points': 100000}, {'width': 0.06, 'signal': 400, 'radius': 0.01, 'mean pulls': -11.642165860618773, 'MC_points': 10000}, {'width': 0.15, 'signal': 400, 'radius': 0.01, 'mean pulls': -10.976682302046736, 'MC_points': 10000}, {'width': 0.06, 'signal': 400, 'radius': 0.05, 'mean pulls': -0.78361427556869001, 'MC_points': 10000}, {'width': 0.15, 'signal': 400, 'radius': 0.05, 'mean pulls': -0.4575686600038944, 'MC_points': 10000}, {'width': 0.06, 'signal': 400, 'radius': 0.1, 'mean pulls': -0.28165486551501673, 'MC_points': 10000}, {'width': 0.15, 'signal': 400, 'radius': 0.1, 'mean pulls': -0.49017077896940614, 'MC_points': 10000}, {'width': 0.06, 'signal': 400, 'radius': 0.15, 'mean pulls': 0.15228558641682671, 'MC_points': 10000}, {'width': 0.15, 'signal': 400, 'radius': 0.15, 'mean pulls': 0.2628542175121294, 'MC_points': 10000}, {'width': 0.06, 'signal': 400, 'radius': 0.2, 'mean pulls': 0.12905129423510187, 'MC_points': 10000}, {'width': 0.15, 'signal': 400, 'radius': 0.2, 'mean pulls': 0.13445516908681565, 'MC_points': 10000}, {'width': 0.06, 'signal': 400, 'radius': 0.01, 'mean pulls': -2.1535278291959883, 'MC_points': 100000}, {'width': 0.15, 'signal': 400, 'radius': 0.01, 'mean pulls': -2.88895182988403, 'MC_points': 100000}, {'width': 0.06, 'signal': 400, 'radius': 0.05, 'mean pulls': -0.21140052921652033, 'MC_points': 100000}, {'width': 0.15, 'signal': 400, 'radius': 0.05, 'mean pulls': 0.13380152413672786, 'MC_points': 100000}, {'width': 0.06, 'signal': 400, 'radius': 0.1, 'mean pulls': 0.2352773681526191, 'MC_points': 100000}, {'width': 0.15, 'signal': 400, 'radius': 0.1, 'mean pulls': 0.35864182002742295, 'MC_points': 100000}, {'width': 0.06, 'signal': 400, 'radius': 0.15, 'mean pulls': 0.19280347526310831, 'MC_points': 100000}, {'width': 0.15, 'signal': 400, 'radius': 0.15, 'mean pulls': -0.47170058416159766, 'MC_points': 100000}, {'width': 0.06, 'signal': 400, 'radius': 0.2, 'mean pulls': 0.697 ...
# [{'width': 0.06, 'signal': 200, 'radius': 0.01, 'mean stds': 0.80318423040970999, 'MC_points': 10000}, {'width': 0.15, 'signal': 200, 'radius': 0.01, 'mean stds': 1.2325112014907547, 'MC_points': 10000}, {'width': 0.06, 'signal': 200, 'radius': 0.05, 'mean stds': 1.0681339025555798, 'MC_points': 10000}, {'width': 0.15, 'signal': 200, 'radius': 0.05, 'mean stds': 1.5433175684012663, 'MC_points': 10000}, {'width': 0.06, 'signal': 200, 'radius': 0.1, 'mean stds': 1.1620128957084963, 'MC_points': 10000}, {'width': 0.15, 'signal': 200, 'radius': 0.1, 'mean stds': 1.0630319796121166, 'MC_points': 10000}, {'width': 0.06, 'signal': 200, 'radius': 0.15, 'mean stds': 1.0494899775376316, 'MC_points': 10000}, {'width': 0.15, 'signal': 200, 'radius': 0.15, 'mean stds': 0.87866241045513382, 'MC_points': 10000}, {'width': 0.06, 'signal': 200, 'radius': 0.2, 'mean stds': 1.0900683398311537, 'MC_points': 10000}, {'width': 0.15, 'signal': 200, 'radius': 0.2, 'mean stds': 0.71647178772381814, 'MC_points': 10000}, {'width': 0.06, 'signal': 200, 'radius': 0.01, 'mean stds': 1.0817615791507689, 'MC_points': 100000}, {'width': 0.15, 'signal': 200, 'radius': 0.01, 'mean stds': 0.98118292082197067, 'MC_points': 100000}, {'width': 0.06, 'signal': 200, 'radius': 0.05, 'mean stds': 0.98194812601968517, 'MC_points': 100000}, {'width': 0.15, 'signal': 200, 'radius': 0.05, 'mean stds': 0.79371032770326255, 'MC_points': 100000}, {'width': 0.06, 'signal': 200, 'radius': 0.1, 'mean stds': 0.94342444961557748, 'MC_points': 100000}, {'width': 0.15, 'signal': 200, 'radius': 0.1, 'mean stds': 0.89790726451995917, 'MC_points': 100000}, {'width': 0.06, 'signal': 200, 'radius': 0.15, 'mean stds': 0.90791333796528806, 'MC_points': 100000}, {'width': 0.15, 'signal': 200, 'radius': 0.15, 'mean stds': 0.73328502511679661, 'MC_points': 100000}, {'width': 0.06, 'signal': 200, 'radius': 0.2, 'mean stds': 0.95988632907892979, 'MC_points': 100000}, {'width': 0.15, 'signal': 200, 'radius': 0.2, 'mean stds': 0.62345060738766966, 'MC_points': 100000}, {'width': 0.06, 'signal': 400, 'radius': 0.01, 'mean stds': 0.9904023839654188, 'MC_points': 10000}, {'width': 0.15, 'signal': 400, 'radius': 0.01, 'mean stds': 0.70523559896648846, 'MC_points': 10000}, {'width': 0.06, 'signal': 400, 'radius': 0.05, 'mean stds': 0.86795212821698786, 'MC_points': 10000}, {'width': 0.15, 'signal': 400, 'radius': 0.05, 'mean stds': 0.96028729654630451, 'MC_points': 10000}, {'width': 0.06, 'signal': 400, 'radius': 0.1, 'mean stds': 1.4698554990029773, 'MC_points': 10000}, {'width': 0.15, 'signal': 400, 'radius': 0.1, 'mean stds': 1.1733670259602769, 'MC_points': 10000}, {'width': 0.06, 'signal': 400, 'radius': 0.15, 'mean stds': 1.0605434279629593, 'MC_points': 10000}, {'width': 0.15, 'signal': 400, 'radius': 0.15, 'mean stds': 0.95051997454786352, 'MC_points': 10000}, {'width': 0.06, 'signal': 400, 'radius': 0.2, 'mean stds': 1.4436974990875397, 'MC_points': 10000}, {'width': 0.15, 'signal': 400, 'radius': 0.2, 'mean stds': 1.2384770361977324, 'MC_points': 10000}, {'width': 0.06, 'signal': 400, 'radius': 0.01, 'mean stds': 0.80386621160088834, 'MC_points': 100000}, {'width': 0.15, 'signal': 400, 'radius': 0.01, 'mean stds': 1.0815319654576372, 'MC_points': 100000}, {'width': 0.06, 'signal': 400, 'radius': 0.05, 'mean stds': 0.84015669234390422, 'MC_points': 100000}, {'width': 0.15, 'signal': 400, 'radius': 0.05, 'mean stds': 1.0890100843349706, 'MC_points': 100000}, {'width': 0.06, 'signal': 400, 'radius': 0.1, 'mean stds': 1.0278896972947646, 'MC_points': 100000}, {'width': 0.15, 'signal': 400, 'radius': 0.1, 'mean stds': 1.3626684451114761, 'MC_points': 100000}, {'width': 0.06, 'signal': 400, 'radius': 0.15, 'mean stds': 0.96083740853403865, 'MC_points': 100000}, {'width': 0.15, 'signal': 400, 'radius': 0.15, 'mean stds': 0.94659603668394809, 'MC_points': 100000}, {'width': 0.06, 'signal': 400, 'radius': 0.2, 'mean stds': 0.95239191641888465, 'MC_points': 100000}, {'width': 0.15, 'signal': 400, 'rad ...
# --------------------

# %%
plt.figure()
colors=['b','g','y','r']
markers=['o','^','+']
marker_sizes=[5,10,60]
labels=[]

for item in means800:
    label='MC=' + str(item['MC_points']) + ' width='+str(item['width'])+ ' signal=' + str(item['signal'])
    if item['MC_points']== MC_list[0]:
        color=colors[0]
    if item['MC_points']==MC_list[1]:
        color=colors[1]
        
    if item['signal']==sig_list[0]:
        marker=markers[0]
    if item['signal']==sig_list[1]:
        marker=markers[1]
        
    if item['width']==width_list[0]:
        marker_size=marker_sizes[0]
    if item['width']==width_list[1]:
        marker_size=marker_sizes[1]
        
    for x in labels:
        if label==x:
            label=""
            
    plt.plot(item['radius'],item['mean pulls'], color=color, marker=marker,markersize=marker_size,label=label)
    labels.append(label)

plt.legend(loc='center left', bbox_to_anchor=(0.6,0.5))
#plt.ylim(-1,.1)
#plt.ylim(-.5,.5)
labels=[]

plt.figure()
for item in stds800:
    label='MC=' + str(item['MC_points']) + ' width='+str(item['width'])+ ' signal=' + str(item['signal'])
    if item['MC_points']== MC_list[0]:
        color=colors[0]
    if item['MC_points']==MC_list[1]:
        color=colors[1]
    if item['signal']==sig_list[0]:
        marker=markers[0]
    if item['signal']==sig_list[1]:
        marker=markers[1]
    if item['width']==width_list[0]:
        marker_size=marker_sizes[0]
    if item['width']==width_list[1]:
        marker_size=marker_sizes[1]
    for x in labels:
        if label==x:
            label=""
            
    plt.plot(item['radius'],item['mean stds'], color=color, marker=marker,markersize=marker_size,label=label)
labels.append(label)

plt.legend(loc='center left', bbox_to_anchor=(0.6,0.5))
#plt.xlim(0,.15)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
